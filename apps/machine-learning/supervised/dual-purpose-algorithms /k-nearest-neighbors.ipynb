# %% [markdown]
# # K-Nearest Neighbors (KNN)
#
# KNN is a **lazy** (instance-based) algorithm: to predict a point's label, it looks at the `k` closest training points (by distance, usually Euclidean) and takes a **majority vote**:
#
# $$\hat{y}(x) = \text{mode}\big(\{y_i : x_i \in \mathcal{N}_k(x)\}\big)$$
#
# No training model is stored - just the data. Works for both classification and regression (regression = average of neighbors).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# 2-feature, 2-class dataset (same as the tree / NB examples)
np.random.seed(1)
n = 60
c0 = np.random.multivariate_normal([2, 3], [[2.0, 0], [0, 0.5]], n)
c1 = np.random.multivariate_normal([6, 4], [[0.5, 0], [0, 2.0]], n)
X = np.vstack([c0, c1])
y = np.array([0] * n + [1] * n)

# %% [markdown]
# ## Train and evaluate (k = 5)

# %%
knn = KNeighborsClassifier(n_neighbors=5).fit(X, y)
preds = knn.predict(X)
print(f"Accuracy        : {accuracy_score(y, preds):.3f}")
print("Confusion matrix:")
print(confusion_matrix(y, preds))

# %% [markdown]
# ## Decision boundary

# %%
x1, x2 = X[:, 0], X[:, 1]
xx, yy = np.meshgrid(np.linspace(x1.min()-1, x1.max()+1, 200),
                     np.linspace(x2.min()-1, x2.max()+1, 200))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

plt.figure(figsize=(6, 4.5))
plt.contourf(xx, yy, Z, alpha=0.25, cmap="coolwarm")
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="coolwarm", edgecolor="k")
plt.title("KNN decision boundary (k=5)")
plt.xlabel("Feature 1"); plt.ylabel("Feature 2")
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Takeaways
#
# - No explicit training; predictions come straight from the data.
# - Small `k` -> wiggly boundary (low bias, high variance); large `k` -> smoother.
# - Scale matters: standardize features before KNN.
